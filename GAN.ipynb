# %%
from GAN import GAN

from prepare_data import prepare_data

print("Reading data....")
trainX_data, trainY_data, testX_data, testY_data = prepare_data()
print("Data read!")

epochs = 50
eta = 0.000001

# epochs = 100
# eta = 0.000005


g = GAN(eta, trainX_data, trainY_data, testX_data, testY_data, 100, epochs)
g.train_model()
g.display_graph()

print(
    f"Training accuracy with 10 hidden layer outputs: {g.train_accuracy()}")
print(
    f"Testing accuracy with 10 hidden layer outputs: {g.test_accuracy()}\n")
# Out:
# Reading data....
# Data read!
# 100%|██████████| 50/50 [03:47<00:00,  4.55s/it]
# Training accuracy with 10 hidden layer outputs: 20.0
# Testing accuracy with 10 hidden layer outputs: 13.900000000000002
