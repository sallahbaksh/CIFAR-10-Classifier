# %%
from GAN import GAN

from prepare_data import prepare_data

print("Reading data....")
trainX_data, trainY_data, testX_data, testY_data = prepare_data()
print("Data read!")

epochs = 50
eta = 0.000001

# epochs = 100
# eta = 0.000005


g = GAN(eta, trainX_data, trainY_data, testX_data, testY_data, 100, epochs)
g.train_model()
g.display_graph()

print(
    f"Training accuracy with 10 hidden layer outputs: {g.train_accuracy()}")
print(
    f"Testing accuracy with 10 hidden layer outputs: {g.test_accuracy()}\n")
# Out:
# Reading data....
# Data read!
#   1%|          | 1/100 [00:06<10:29,  6.36s/it]
# Training accuracy with 10 hidden layer outputs: 11.0
# Testing accuracy with 10 hidden layer outputs: 10.13
#  11%|█         | 11/100 [01:06<08:23,  5.66s/it]
# Training accuracy with 10 hidden layer outputs: 11.0
# Testing accuracy with 10 hidden layer outputs: 10.0
#  21%|██        | 21/100 [02:10<09:16,  7.05s/it]
# Training accuracy with 10 hidden layer outputs: 12.0
# Testing accuracy with 10 hidden layer outputs: 10.0
#  31%|███       | 31/100 [03:10<06:06,  5.31s/it]
# Training accuracy with 10 hidden layer outputs: 14.000000000000002
# Testing accuracy with 10 hidden layer outputs: 10.0
#  41%|████      | 41/100 [04:06<05:51,  5.96s/it]
# Training accuracy with 10 hidden layer outputs: 13.0
# Testing accuracy with 10 hidden layer outputs: 10.0
#  51%|█████     | 51/100 [05:00<04:16,  5.23s/it]
# Training accuracy with 10 hidden layer outputs: 7.000000000000001
# Testing accuracy with 10 hidden layer outputs: 10.0
#  61%|██████    | 61/100 [05:56<03:59,  6.15s/it]
# Training accuracy with 10 hidden layer outputs: 6.0
# Testing accuracy with 10 hidden layer outputs: 10.0
#  71%|███████   | 71/100 [06:50<02:31,  5.22s/it]
# Training accuracy with 10 hidden layer outputs: 6.0
# Testing accuracy with 10 hidden layer outputs: 10.0
#  81%|████████  | 81/100 [07:48<01:56,  6.12s/it]
# Training accuracy with 10 hidden layer outputs: 14.000000000000002
# Testing accuracy with 10 hidden layer outputs: 10.0
#  91%|█████████ | 91/100 [08:46<00:46,  5.19s/it]
# Training accuracy with 10 hidden layer outputs: 10.0
# Testing accuracy with 10 hidden layer outputs: 10.0
# 100%|██████████| 100/100 [09:29<00:00,  5.69s/it]
# Training accuracy with 10 hidden layer outputs: 7.000000000000001
# Testing accuracy with 10 hidden layer outputs: 10.0
